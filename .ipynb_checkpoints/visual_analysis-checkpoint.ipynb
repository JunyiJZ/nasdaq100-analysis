# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Set plot style
plt.style.use('seaborn-v0_8-darkgrid')
# This is for displaying Chinese characters if your system supports it. If not, it's okay.
plt.rcParams['font.sans-serif'] = ['SimHei']  # SimHei is a common Chinese font
plt.rcParams['axes.unicode_minus'] = False  # To display the minus sign correctly

# --- Load the feature data we created ---
# Define the file path
BASE_DIR = os.getcwd() # Gets the current directory of the notebook
FEATURES_FILE = os.path.join(BASE_DIR, 'features_technical.csv')

# Load the data, parsing the 'Date' column as dates
df = pd.read_csv(FEATURES_FILE, parse_dates=['Date'])

print("Data loaded successfully!")
print(f"The dataset contains {df['ticker'].nunique()} unique stocks.")
df.head()
# Out:
# Data loaded successfully!
# The dataset contains 101 unique stocks.
#         Date ticker     Close      High       Low      Open       Volume  \
# 0 2000-03-14   AAPL  0.857449  0.932500  0.855573  0.909750  428579200.0
# 1 2000-03-15   AAPL  0.872459  0.902480  0.856511  0.867769  443609600.0
# 2 2000-03-16   AAPL  0.912330  0.915614  0.859325  0.880434  378100800.0
# 3 2000-03-17   AAPL  0.938128  0.938128  0.897789  0.901542  305043200.0
# 4 2000-03-20   AAPL  0.923118  0.947510  0.918428  0.926872  204489600.0
#
#      SMA_20    EMA_50     RSI_14  ...  BBL_20_2.0_2.0  BBM_20_2.0_2.0  \
# 0  0.892049  0.830715  44.220538  ...        0.804480        0.892049
# 1  0.891017  0.832352  46.192471  ...        0.803015        0.891017
# 2  0.893808  0.835489  51.134154  ...        0.806879        0.893808
# 3  0.897607  0.839514  54.073344  ...        0.809868        0.897607
# 4  0.902016  0.842792  52.109507  ...        0.818791        0.902016
#
#    BBU_20_2.0_2.0  BBB_20_2.0_2.0  BBP_20_2.0_2.0   ATRr_14  volatility_20d  \
# 0        0.979618       19.633222        0.302443  0.055030        0.043784
# 1        0.979019       19.753220        0.394561  0.054382        0.044001
# 2        0.980736       19.451276        0.606535  0.054519        0.043464
# 3        0.985347       19.549625        0.730917  0.053506        0.043870
# 4        0.985242       18.453172        0.626776  0.051761        0.041613
#
#    returns_1d  returns_3d  returns_5d
# 0   -0.058218   -0.065440   -0.070194
# 1    0.017506   -0.075547   -0.047132
# 2    0.045699    0.002061   -0.005624
# 3    0.028278    0.094092   -0.005965
# 4   -0.016000    0.058065    0.013910
#
# [5 rows x 23 columns]

# %%
# We will select 'AAPL' as our example for visualization
ticker_df = df[df['ticker'] == 'AAPL'].copy()

# To make the plot clearer, let's focus on the data from the year 2001
ticker_df = ticker_df[(ticker_df['Date'] >= '2001-01-01') & (ticker_df['Date'] <= '2001-12-31')]

# Set the 'Date' column as the index, which is useful for time-series plotting
ticker_df.set_index('Date', inplace=True)

print(f"Filtered for 'AAPL' data in 2001. Total records: {len(ticker_df)}.")
# Out:
# Filtered for 'AAPL' data in 2001. Total records: 248.

# %%
# ===================================================================
# 修正后的代码：先加载数据，再计算指标
# ===================================================================

# 1. 导入需要的库
import pandas as pd
import pandas_ta as ta

# 2. 加载数据并创建 ticker_df
#    !!! 这是最关键的一步，请根据您的实际情况修改 !!!
try:
    # --- 用户需要修改的部分 ---
    # 请将 'features_technical.csv' 替换为您的实际数据文件名。
    # 从您左侧的文件列表看，'features_technical.csv' 可能是正确的文件。
    file_path = 'features_technical.csv'  # <--- 如果文件名不同，请在这里修改！
    
    # 从CSV文件加载数据
    df = pd.read_csv(file_path)
    
    # --- 数据预处理 ---
    # 确保日期列 'Date' 是日期格式，并设为索引 (这对时间序列分析很重要)
    if 'Date' in df.columns:
        df['Date'] = pd.to_datetime(df['Date'])
        df.set_index('Date', inplace=True)
    
    # pandas-ta库默认使用小写的'close'列，如果您的列名是'Close'，我们将其重命名
    if 'Close' in df.columns and 'close' not in df.columns:
        df.rename(columns={'Close': 'close'}, inplace=True)

    # 在这里，我们将整个加载的数据作为 ticker_df。
    # 如果您需要筛选特定股票（如'AAPL'），可以取消下面这行的注释并修改
    # df = df[df['Ticker'] == 'AAPL'] 
    
    ticker_df = df.copy() # 使用 .copy() 是一个好习惯，避免警告
    
    print(f"成功从 '{file_path}' 加载数据并创建了 'ticker_df'。")
    print("数据预览 (前5行):")
    print(ticker_df.head())

except FileNotFoundError:
    print(f"错误：找不到文件 '{file_path}'！请确认文件名和路径是否正确。")
    # 创建一个空的DataFrame，以防后续单元格因变量不存在而报错
    ticker_df = pd.DataFrame()

# 3. 检查并计算技术指标 (这部分是您原有的代码)
if not ticker_df.empty:
    # 检查 ticker_df 中是否已有技术指标, 避免重复计算
    if 'BBU_20_2.0' not in ticker_df.columns:
        print("\n未找到技术指标列，现在开始计算...")

        # 使用 pandas-ta 为 ticker_df 添加布林带指标
        # Length=20, std=2.0, 这会生成 'BBU_20_2.0', 'BBM_20_2.0', 'BBL_20_2.0' 等列
        ticker_df.ta.bbands(length=20, std=2.0, append=True)

        # 使用 pandas-ta 为 ticker_df 添加 RSI 指标
        # Length=14, 这会生成 'RSI_14' 列
        ticker_df.ta.rsi(length=14, append=True)

        print("\n成功添加布林带 (Bollinger Bands) 和 RSI 指标。")
        print("\n'ticker_df' 中新的列名:")
        print(ticker_df.columns)
    else:
        print("\n技术指标列已存在，无需重复计算。")

    # 显示 DataFrame 的最后几行, 以确认新列已添加且有数据
    print("\n显示包含新指标的 DataFrame 最后几行:")
    print(ticker_df.tail())
else:
    print("\n'ticker_df' 为空，跳过了技术指标计算。请检查数据加载步骤。")
# Out:
# 成功从 'features_technical.csv' 加载数据并创建了 'ticker_df'。
# 数据预览 (前5行):
#            ticker     close      High       Low      Open       Volume  \
# Date
# 2000-03-14   AAPL  0.857449  0.932500  0.855573  0.909750  428579200.0
# 2000-03-15   AAPL  0.872459  0.902480  0.856511  0.867769  443609600.0
# 2000-03-16   AAPL  0.912330  0.915614  0.859325  0.880434  378100800.0
# 2000-03-17   AAPL  0.938128  0.938128  0.897789  0.901542  305043200.0
# 2000-03-20   AAPL  0.923118  0.947510  0.918428  0.926872  204489600.0
#
#               SMA_20    EMA_50     RSI_14  MACD_12_26_9  ...  BBL_20_2.0_2.0  \
# Date                                                     ...
# 2000-03-14  0.892049  0.830715  44.220538      0.024275  ...        0.804480
# 2000-03-15  0.891017  0.832352  46.192471      0.020033  ...        0.803015
# 2000-03-16  0.893808  0.835489  51.134154      0.019662  ...        0.806879
# 2000-03-17  0.897607  0.839514  54.073344      0.021205  ...        0.809868
# 2000-03-20  0.902016  0.842792  52.109507      0.020975  ...        0.818791
#
#             BBM_20_2.0_2.0  BBU_20_2.0_2.0  BBB_20_2.0_2.0  BBP_20_2.0_2.0  \
# Date
# 2000-03-14        0.892049        0.979618       19.633222        0.302443
# 2000-03-15        0.891017        0.979019       19.753220        0.394561
# 2000-03-16        0.893808        0.980736       19.451276        0.606535
# 2000-03-17        0.897607        0.985347       19.549625        0.730917
# 2000-03-20        0.902016        0.985242       18.453172        0.626776
#
#              ATRr_14  volatility_20d  returns_1d  returns_3d  returns_5d
# Date
# 2000-03-14  0.055030        0.043784   -0.058218   -0.065440   -0.070194
# 2000-03-15  0.054382        0.044001    0.017506   -0.075547   -0.047132
# 2000-03-16  0.054519        0.043464    0.045699    0.002061   -0.005624
# 2000-03-17  0.053506        0.043870    0.028278    0.094092   -0.005965
# 2000-03-20  0.051761        0.041613   -0.016000    0.058065    0.013910
#
# [5 rows x 22 columns]
#
# 未找到技术指标列，现在开始计算...
#
# 成功添加布林带 (Bollinger Bands) 和 RSI 指标。
#
# 'ticker_df' 中新的列名:
# Index(['ticker', 'close', 'High', 'Low', 'Open', 'Volume', 'SMA_20', 'EMA_50',
#        'RSI_14', 'MACD_12_26_9', 'MACDh_12_26_9', 'MACDs_12_26_9',
#        'BBL_20_2.0_2.0', 'BBM_20_2.0_2.0', 'BBU_20_2.0_2.0', 'BBB_20_2.0_2.0',
#        'BBP_20_2.0_2.0', 'ATRr_14', 'volatility_20d', 'returns_1d',
#        'returns_3d', 'returns_5d'],
#       dtype='object')
#
# 显示包含新指标的 DataFrame 最后几行:
#            ticker       close        High         Low        Open     Volume  \
# Date
# 2025-10-20     ZS  305.899994  307.190002  301.269989  301.269989   880700.0
# 2025-10-21     ZS  310.369995  311.290009  303.779999  305.739990   748500.0
# 2025-10-22     ZS  307.920013  311.339996  302.579987  308.980011  1171400.0
# 2025-10-23     ZS  318.769989  319.205994  307.994995  308.000000  1397100.0
# 2025-10-24     ZS  323.000000  327.394989  321.000000  321.380005  1063200.0
#
#                 SMA_20      EMA_50     RSI_14  MACD_12_26_9  ...  \
# Date                                                         ...
# 2025-10-20  301.432500  292.589698  56.177276      4.686081  ...
# 2025-10-21  302.486499  293.286965  59.131232      4.905944  ...
# 2025-10-22  303.661499  293.860810  56.868584      4.826854  ...
# 2025-10-23  305.266998  294.837641  63.525070      5.575407  ...
# 2025-10-24  306.684499  295.942047  65.744681      6.435779  ...
#
#             BBL_20_2.0_2.0  BBM_20_2.0_2.0  BBU_20_2.0_2.0  BBB_20_2.0_2.0  \
# Date
# 2025-10-20      283.923928      301.432500      318.941072       11.616910
# 2025-10-21      285.526277      302.486499      319.446721       11.213870
# 2025-10-22      288.851502      303.661499      318.471496        9.754280
# 2025-10-23      291.278213      305.266998      319.255784        9.164951
# 2025-10-24      291.528735      306.684499      321.840262        9.883619
#
#             BBP_20_2.0_2.0   ATRr_14  volatility_20d  returns_1d  returns_3d  \
# Date
# 2025-10-20        0.627580  9.544967        8.754286    0.018818    0.011741
# 2025-10-21        0.732411  9.399613        8.480111    0.014613    0.037194
# 2025-10-22        0.643772  9.353927        7.404998   -0.007894    0.025545
# 2025-10-23        0.982636  9.491931        6.994393    0.035236    0.042073
# 2025-10-24        1.038261  9.430007        7.577882    0.013270    0.040693
#
#             returns_5d
# Date
# 2025-10-20   -0.022809
# 2025-10-21    0.028396
# 2025-10-22    0.018422
# 2025-10-23    0.065265
# 2025-10-24    0.075770
#
# [5 rows x 22 columns]

# %%
# ===================================================================
# 修正后的代码：先导入绘图库，再进行绘图
# ===================================================================

# 1. 导入绘图库 (这是解决问题的关键新增代码)
import matplotlib.pyplot as plt

# 2. 检查 ticker_df 是否存在 (这是一个好的编程习惯)
#    这可以防止因重启内核或未按顺序运行单元格而导致的错误
if 'ticker_df' in locals() and not ticker_df.empty:
    
    # --- 以下是您原有的绘图代码 ---
    
    # 创建一个包含两个垂直堆叠子图的图形
    # 注意：修正了您原始代码中 gridspec_kw 的引号不匹配问题
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(16, 12), sharex=True, gridspec_kw={'height_ratios': [3, 1]})

    # --- 子图 1: 价格与布林带 ---
    ax1.plot(ticker_df.index, ticker_df['Close'], label='Close Price', color='blue')
    ax1.plot(ticker_df.index, ticker_df['BBU_20_2.0'], label='Upper Bollinger Band', color='orange', linestyle='--')
    ax1.plot(ticker_df.index, ticker_df['BBM_20_2.0'], label='Middle Bollinger Band', color='grey', linestyle=':')
    ax1.plot(ticker_df.index, ticker_df['BBL_20_2.0'], label='Lower Bollinger Band', color='orange', linestyle='--')

    # 填充上下布林带之间的区域
    ax1.fill_between(ticker_df.index, ticker_df['BBL_20_2.0'], ticker_df['BBU_20_2.0'], color='orange', alpha=0.1)

    # 设置子图1的标题和标签
    # 提示：您可以将'AAPL'和'(2001)'替换为更动态的标题，例如从数据中获取股票代码和年份
    ax1.set_title('Stock Price and Bollinger Bands', fontsize=16) 
    ax1.set_ylabel('Price ($)', fontsize=12)
    ax1.legend()
    ax1.grid(True)

    # --- 子图 2: RSI ---
    ax2.plot(ticker_df.index, ticker_df['RSI_14'], label='RSI (14)', color='purple')

    # 绘制超买和超卖水平的水平线
    ax2.axhline(70, linestyle='--', color='red', alpha=0.7, label='Overbought (70)')
    ax2.axhline(30, linestyle='--', color='green', alpha=0.7, label='Oversold (30)')

    # 设置子图2的标题和标签
    ax2.set_title('Relative Strength Index (RSI)', fontsize=16)
    ax2.set_ylabel('RSI Value', fontsize=12)
    ax2.set_xlabel('Date', fontsize=12)
    ax2.legend()
    ax2.grid(True)

    # 调整布局以防止标签重叠
    plt.tight_layout() 
    
    # 显示图形
    plt.show()

else:
    # 如果 ticker_df 不存在，则打印一个友好的提示信息
    print("错误：变量 'ticker_df' 未定义或为空。请先确保已成功运行了加载和处理数据的单元格。")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Desktop\Innovation AI\nasdaq100-analysis\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 19
#      16 fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(16, 12), sharex=True, gridspec_kw={'height_ratios': [3, 1]})
#      18 # --- 子图 1: 价格与布林带 ---
# ---> 19 ax1.plot(ticker_df.index, ticker_df['Close'], label='Close Price', color='blue')
#      20 ax1.plot(ticker_df.index, ticker_df['BBU_20_2.0'], label='Upper Bollinger Band', color='orange', linestyle='--')
#      21 ax1.plot(ticker_df.index, ticker_df['BBM_20_2.0'], label='Middle Bollinger Band', color='grey', linestyle=':')
#
# File ~\Desktop\Innovation AI\nasdaq100-analysis\venv\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\Desktop\Innovation AI\nasdaq100-analysis\venv\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Close'

# %%
# !pip install pandas-ta
# Out:
# Looking in indexes: https://mirrors.tuna.tsinghua.edu.cn/pypi/web/simple
# Requirement already satisfied: pandas-ta in c:\users\rog\desktop\innovation ai\nasdaq100-analysis\venv\lib\site-packages (0.4.71b0)
# Requirement already satisfied: numba==0.61.2 in c:\users\rog\desktop\innovation ai\nasdaq100-analysis\venv\lib\site-packages (from pandas-ta) (0.61.2)
# Requirement already satisfied: numpy>=2.2.6 in c:\users\rog\desktop\innovation ai\nasdaq100-analysis\venv\lib\site-packages (from pandas-ta) (2.2.6)
# Requirement already satisfied: pandas>=2.3.2 in c:\users\rog\desktop\innovation ai\nasdaq100-analysis\venv\lib\site-packages (from pandas-ta) (2.3.3)
# Requirement already satisfied: tqdm>=4.67.1 in c:\users\rog\desktop\innovation ai\nasdaq100-analysis\venv\lib\site-packages (from pandas-ta) (4.67.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\rog\desktop\innovation ai\nasdaq100-analysis\venv\lib\site-packages (from numba==0.61.2->pandas-ta) (0.44.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rog\desktop\innovation ai\nasdaq100-analysis\venv\lib\site-packages (from pandas>=2.3.2->pandas-ta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rog\desktop\innovation ai\nasdaq100-analysis\venv\lib\site-packages (from pandas>=2.3.2->pandas-ta) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rog\desktop\innovation ai\nasdaq100-analysis\venv\lib\site-packages (from pandas>=2.3.2->pandas-ta) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\rog\desktop\innovation ai\nasdaq100-analysis\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.3.2->pandas-ta) (1.17.0)
# Requirement already satisfied: colorama in c:\users\rog\desktop\innovation ai\nasdaq100-analysis\venv\lib\site-packages (from tqdm>=4.67.1->pandas-ta) (0.4.6)
